# %% [markdown]
# # Quality Control - Cohort B
# Xenium run QC for Cohort B. Uses the shared house thresholds rather than
# hardcoding them, so this cohort filters identically to Cohort A.

# %%
import scanpy as sc
from src.qc_utils import apply_qc
adata = sc.read_h5ad('/data/cohortB/xenium_raw.h5ad')
adata = apply_qc(adata)

# %% [markdown]
# Thresholds come from src/qc_utils.py and are mirrored in config/pipeline_cohortB.yaml.
