# %% [markdown]
# # Figure 4 - Niche composition across the tumour interface
# Combines the spatial niche assignments with distance-to-interface bins.

# %%
import pandas as pd, matplotlib.pyplot as plt
niches = pd.read_csv('results/niche_assignments.csv')
dists = pd.read_csv('results/interface_distances.csv')
merged = niches.merge(dists, on='cell_id')
fig = plot_niche_by_zone(merged)
fig.savefig('results/figure4_interface.png', dpi=300)
